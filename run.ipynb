# %%
# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-1.13.0+cu116.html

# %%
import sys
sys.path.append('/content/drive/MyDrive/anomaly-detection')

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 /content/drive/MyDrive/anomaly-detection/main.py --data_dir '/content/drive/MyDrive/anomaly-detection/alpha_data.pkl' --epochs 500
# Out:
# Namespace(data_dir='/content/drive/MyDrive/anomaly-detection/alpha_data.pkl', saved_dir='saved_model', log_name='log', epochs=500, seed=1, lr=0.0005, min_lr=0.0001, bs=1, input_dim=256, out_dim=256, verbose=1, outer_layer=2, inner_layer=1, is_global=True, is_edge=True, pooling='memory', is_lp=True, lp_weight=0.1)
# [2023-03-18 15:20:46] {model.py:85} INFO - EdgeUpdate
# [2023-03-18 15:20:51] {model.py:90} INFO - NodeUpdate
# [2023-03-18 15:20:51] {model.py:97} INFO - SystemUpdate
# [2023-03-18 15:20:51] {model.py:111} INFO - is_edge: True, is_global: True pooling: 'memory'
# [2023-03-18 15:20:51] {model.py:26} INFO - is_lp: True, lp_weight: 0.100000
# /usr/local/lib/python3.9/dist-packages/torch_geometric/deprecation.py:12: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [2023-03-18 15:20:52] {main.py:119} INFO - Warm up schedular: 500
# 100% 1/1 [00:02<00:00,  2.65s/it]
# ...
